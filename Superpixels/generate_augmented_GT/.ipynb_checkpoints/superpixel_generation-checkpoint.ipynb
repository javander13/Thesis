# %% [markdown]
# # Superpixel generation and groundtruth augmentation
#
# This notebook allows to run the superpixel generation and groundtruth augmentation piece by piece.
#
# *In Litterature*:
#
# - start with 1500 and decrease by 80% at each iteration
# - start with 10x the number of labelled pixels, end with the 10th of labelled pixels
# - start with 5000 to 300, 30 levels

# %% [markdown]
# ## Importing necessary libraries

# %%
from collections import Counter
from imutils import paths
from skimage import io
import argparse
import csv
import cv2
import glob
import numpy as np
import math
import matplotlib.pyplot as plt
import os

# %%
os.chdir('/data/jantina/Superpixels/Datasets/Test/')
im = io.imread("images/test/10A-Copy1.png")
mask = io.imread("labels/test/10A-Copy1.png")
mask[mask==255]=0

os.chdir('/data/jantina/Superpixels/Test/augmented_GT/')
superpixel = io.imread("test/10A-Copy1.png")
fig, ax = plt.subplots(ncols=2, figsize=(15, 15))
ax[0].imshow(im)
ax[0].scatter(np.nonzero(mask)[1], np.nonzero(mask)[0], s=20, marker='.', c='r')
ax[1].imshow(superpixel)
ax[1].scatter(np.nonzero(mask)[1], np.nonzero(mask)[0], s=20, marker='.', c='r')
plt.show()

# %%
os.chdir('/data/jantina/Superpixels/Datasets/Test/')
im = io.imread("images/test/BH10_T1-001-Copy1.png")
mask = io.imread("labels/test/BH10_T1-001-Copy1.png")
mask[mask==255]=0

os.chdir('/data/jantina/Superpixels/Test/augmented_GT/')
superpixel = io.imread("test/BH10_T1-001-Copy1.png")
fig, ax = plt.subplots(ncols=2, figsize=(15, 15))
ax[0].imshow(im)
ax[0].scatter(np.nonzero(mask)[1], np.nonzero(mask)[0], s=20, marker='.', c='r')
ax[1].imshow(superpixel)
ax[1].scatter(np.nonzero(mask)[1], np.nonzero(mask)[0], s=20, marker='.', c='r')
plt.show()

# %%
os.chdir('/data/jantina/Superpixels/Datasets/Test/')
im = io.imread("images/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).JPG")
mask = io.imread("labels/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png")
mask[mask==255]=0

os.chdir('/data/jantina/Superpixels/Test/augmented_GT/')
superpixel = io.imread("train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png")
fig, ax = plt.subplots(ncols=2, figsize=(15, 15))
ax[0].imshow(im)
ax[0].scatter(np.nonzero(mask)[1], np.nonzero(mask)[0], s=20, marker='.', c='r')
ax[1].imshow(superpixel)
ax[1].scatter(np.nonzero(mask)[1], np.nonzero(mask)[0], s=20, marker='.', c='r')
plt.show()

# %%
os.chdir('/data/jantina/Superpixels/Datasets/Test/')
im = io.imread("images/train/KY-M1GOPR0778-Copy1.JPG")
mask = io.imread("labels/train/KY-M1GOPR0778-Copy1.png")
mask[mask==255]=0

os.chdir('/data/jantina/Superpixels/Test/augmented_GT/')
superpixel = io.imread("train/KY-M1GOPR0778-Copy1.png")
fig, ax = plt.subplots(ncols=2, figsize=(15, 15))
ax[0].imshow(im)
ax[0].scatter(np.nonzero(mask)[1], np.nonzero(mask)[0], s=20, marker='.', c='r')
ax[1].imshow(superpixel)
ax[1].scatter(np.nonzero(mask)[1], np.nonzero(mask)[0], s=20, marker='.', c='r')
plt.show()

# %% [markdown]
# ## Configuration

# %%
# value of non-labeled pixels
DEFAULT_VALUE = int(255)

# number of max iterations
NL = int(30)

# number of superpixels in the first iteration
start_superpixels = int(500)

# number of superpixels in the last iteration
last_superpixels = int(30)

# %%
csv_sizes = []
reduction_factor = math.pow(float(last_superpixels) / start_superpixels, 1. / (NL - 1))
for level in range(NL):
    csv_sizes = csv_sizes + [int(round(start_superpixels * math.pow(reduction_factor, level)))]

# %% [markdown]
# ## Which dataset chunk

# %%
dataset = '/data/jantina/Superpixels/Datasets/Test'

sparse_dir = os.path.join('/data/jantina/Superpixels/Test/sparse_GT')
out_dir = os.path.join('/data/jantina/Superpixels/Test/augmented_GT')
superpixels_dir = os.path.join('/data/jantina/Superpixels/Test/superpixels')

folders = ['test', 'train']

# %% [markdown]
# ### Execute superpixel generation

# %%
size_sup_string = " "
for size in csv_sizes:
    size_sup_string = size_sup_string + str(size) + " "

# %cd /data/jantina/Superpixels/
os.system("sh /home/jantina/CoralNet/Superpixels/generate_superpixels/generate_superpixels.sh " + dataset + size_sup_string)
# Out:
# /data/jantina/Superpixels
# 2 images total ...
# On average, 8.19974 seconds needed ...
# 2 images total ...
# On average, 1.7112 seconds needed ...
# 2 images total ...
# On average, 7.82401 seconds needed ...
# 2 images total ...
# On average, 1.3545 seconds needed ...
# 2 images total ...
# On average, 1.83766 seconds needed ...
# 2 images total ...
# On average, 0.428782 seconds needed ...
# 2 images total ...
# On average, 1.67381 seconds needed ...
# 2 images total ...
# On average, 0.333735 seconds needed ...
# 2 images total ...
# On average, 1.4653 seconds needed ...
# 2 images total ...
# On average, 0.304924 seconds needed ...
# 2 images total ...
# On average, 1.433 seconds needed ...
# 2 images total ...
# On average, 0.255368 seconds needed ...
# 2 images total ...
# On average, 2.21825 seconds needed ...
# 2 images total ...
# On average, 1.29978 seconds needed ...
# 2 images total ...
# On average, 5.31089 seconds needed ...
# 2 images total ...
# On average, 1.2093 seconds needed ...
# 2 images total ...
# On average, 5.49751 seconds needed ...
# 2 images total ...
# On average, 1.15139 seconds needed ...
# 2 images total ...
# On average, 5.30567 seconds needed ...
# 2 images total ...
# On average, 1.04004 seconds needed ...
# 2 images total ...
# On average, 5.57339 seconds needed ...
# 2 images total ...
# On average, 0.293129 seconds needed ...
# 2 images total ...
# On average, 2.24949 seconds needed ...
# 2 images total ...
# On average, 0.461402 seconds needed ...
# 2 images total ...
# On average, 2.04926 seconds needed ...
# 2 images total ...
# On average, 0.394559 seconds needed ...
# 2 images total ...
# On average, 1.89117 seconds needed ...
# 2 images total ...
# On average, 0.238508 seconds needed ...
# 2 images total ...
# On average, 5.95524 seconds needed ...
# 2 images total ...
# On average, 1.48809 seconds needed ...
# 2 images total ...
# On average, 6.87362 seconds needed ...
# 2 images total ...
# On average, 1.53456 seconds needed ...
# 2 images total ...
# On average, 6.78339 seconds needed ...
# 2 images total ...
# On average, 1.52447 seconds needed ...
# 2 images total ...
# On average, 4.88405 seconds needed ...
# 2 images total ...
# On average, 0.235908 seconds needed ...
# 2 images total ...
# On average, 1.02458 seconds needed ...
# 2 images total ...
# On average, 0.291308 seconds needed ...
# 2 images total ...
# On average, 1.39567 seconds needed ...
# 2 images total ...
# On average, 0.299153 seconds needed ...
# 2 images total ...
# On average, 1.28168 seconds needed ...
# 2 images total ...
# On average, 0.259045 seconds needed ...
# 2 images total ...
# On average, 1.23831 seconds needed ...
# 2 images total ...
# On average, 0.20553 seconds needed ...
# 2 images total ...
# On average, 1.16989 seconds needed ...
# 2 images total ...
# On average, 0.931237 seconds needed ...
# 2 images total ...
# On average, 4.75355 seconds needed ...
# 2 images total ...
# On average, 0.933341 seconds needed ...
# 2 images total ...
# On average, 4.4768 seconds needed ...
# 2 images total ...
# On average, 1.5761 seconds needed ...
# 2 images total ...
# On average, 4.55277 seconds needed ...
# 2 images total ...
# On average, 1.46422 seconds needed ...
# 2 images total ...
# On average, 6.81926 seconds needed ...
# 2 images total ...
# On average, 0.273918 seconds needed ...
# 2 images total ...
# On average, 1.30012 seconds needed ...
# 2 images total ...
# On average, 0.292811 seconds needed ...
# 2 images total ...
# On average, 1.96755 seconds needed ...
# 2 images total ...
# On average, 0.295274 seconds needed ...
# 2 images total ...
# On average, 1.73962 seconds needed ...
# 2 images total ...
# On average, 0.281134 seconds needed ...
# superpixel generation completed
# 0

# %% [markdown]
# ## Classes

# %%
class Superpixel:
    def __init__(self, maxlength=10000): #10000000
        self.lista_x = np.zeros([maxlength], dtype=np.int16)
        self.lista_y = np.zeros([maxlength], dtype=np.int16)
        self.lista_x[:]=-1
        self.lista_y[:]=-1
        self.index = 0

    def add(self, value_x, value_y):
        if self.index >= len(self.lista_x):
            #make it bigger
            new_size = len(self.lista_x)*10
            lista_x_new = np.zeros([new_size], dtype=np.int16)
            lista_y_new = np.zeros([new_size], dtype=np.int16)
            lista_x_new[:] = -1
            lista_y_new[:] = -1

            lista_x_new[:len(self.lista_x)] = self.lista_x
            lista_y_new[:len(self.lista_y)] = self.lista_y
            self.lista_x = lista_x_new
            self.lista_y = lista_y_new

        self.lista_x[self.index]=value_x
        self.lista_y[self.index]=value_y
        self.index += 1

    def clean(self):
        self.lista_x = self.lista_x[self.lista_x>=0]
        self.lista_y = self.lista_y[self.lista_y>=0]

# %%
def label_mayoria_x_y(superpixel, gt):
    '''Given a superpixel and a GT image, returns the label value of the superpixel'''
    
    # pixel label values of the superpixels
    pixel_values = gt[superpixel.lista_x.astype(int), superpixel.lista_y.astype(int)]
    # pixel label values of the superpixels excluding the default value
    values_labels = pixel_values[pixel_values < DEFAULT_VALUE]
    # returns the value which appears the most
    if len(values_labels) == 0:
        return DEFAULT_VALUE
    else:
        count = Counter(values_labels)
        return count.most_common()[0][0]

# %%
def image_superpixels_gt(csv_name, gt_name, n_superpixels):
    '''Given a csv file with segmentations (csv_name) and a sparse GT image (gt_name),
        returns Superpixel-augmented GT image'''
    
    print(gt_name)
    gt = cv2.imread(gt_name, 0)
    blank_image = np.zeros((gt.shape[0], gt.shape[1], 1), np.uint8)

    superpixels = {}

    for i in range(n_superpixels*2):
        superpixels[str(i)] = Superpixel()

    # for each csv segmentation file, creates the Superpixel class
    with open(csv_name, 'r') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
        i = 0
        for row in spamreader:
            fila = row[0].split(',')
            fila_count = len(fila)
            for j in range(fila_count):
                superpixel_index = fila[j]
                # the pixel here is (i, j). (superpixel_index) is the segmentation which the pixel belongs to
                # add the pixel  to the Superpixel instance
                superpixels[superpixel_index].add(i, j)
            i = i + 1

    # for each superpixel, gets its label value and writes it into the image to return
    for index in range(len(superpixels)):
        superpixels[str(index)].clean()
        label_superpixel = label_mayoria_x_y(superpixels[str(index)], gt)
        blank_image[superpixels[str(index)].lista_x.astype(int), 
                    superpixels[str(index)].lista_y.astype(int)] = int(label_superpixel)

    return blank_image

# %%
# %cd /data/jantina/Superpixels/

def generar_augmentedGT():
    for folder in folders:

        in_folder = os.path.join(sparse_dir, folder)
        out_folder = os.path.join(out_dir, folder)
        superpixels_folder = os.path.join(superpixels_dir, folder)

        if not os.path.exists(out_folder):
            os.makedirs(out_folder)
            
        print(in_folder + '/*.' + 'png')
  
        for filename in glob.glob(in_folder + '/*.' + 'png'):
            gt_name = filename.split('/')[-1]
            gt_filename = os.path.join(out_folder, gt_name)
            # for each different segmentation generated
            for index in range(len(csv_sizes)):
                print(csv_sizes[index])

                csv_name = os.path.join(superpixels_folder, 'superpixels_' + str(csv_sizes[index]),
                                        gt_name.replace('.' + 'png', '') + '.csv')

                if index == 0:
                    # creates the first one (it has to be the more detailed one, the segmentation with more segments)
                    image_gt_new = image_superpixels_gt(csv_name, filename, csv_sizes[index])
                else:
                    # mask it with the less detailed segmentations in order to fill the areas with no valid labels
                    image_gt_new_low = image_superpixels_gt(csv_name, filename, csv_sizes[index])
                    image_gt_new[image_gt_new == DEFAULT_VALUE] = image_gt_new_low[image_gt_new == DEFAULT_VALUE]
                    print(image_gt_new.shape)
                # cv2.imwrite(gt_filename.replace(gt_name, gt_name.replace('.png', '_'+str(csv_sizes[index])+'.png')),image_gt_new)

            # out_dir
            cv2.imwrite(gt_filename, image_gt_new)
# Out:
# /data/jantina/Superpixels

# %% [markdown]
# ## Generate augmented groundtruth

# %%
generar_augmentedGT()
print('[INFO] generation completed')
# Out:
# /data/jantina/Superpixels/Test/sparse_GT/test/*.png
# 500
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# 454
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 412
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 374
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 339
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 308
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 279
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 254
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 230
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 209
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 190
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 172
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 156
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 142
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 129
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 117
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 106
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 96
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 87
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 79
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 72
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 65
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 59
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 54
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 49
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 44
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 40
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 36
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 33
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 30
# /data/jantina/Superpixels/Test/sparse_GT/test/10A-Copy1.png
# (1308, 2328, 1)
# 500
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# 454
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# 412
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# 374
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# 339
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# 308
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# 279
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# 254
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# 230
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# 209
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# 190
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# 172
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# 156
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# 142
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# 129
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# 117
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# 106
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# 96
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# 87
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# 79
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# 72
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# 65
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# 59
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# 54
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# 49
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# 44
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# 40
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# 36
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# 33
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# 30
# /data/jantina/Superpixels/Test/sparse_GT/test/BH10_T1-001-Copy1.png
# (849, 584, 1)
# /data/jantina/Superpixels/Test/sparse_GT/train/*.png
# 500
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# 454
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 412
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 374
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 339
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 308
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 279
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 254
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 230
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 209
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 190
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 172
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 156
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 142
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 129
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 117
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 106
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 96
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 87
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 79
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 72
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 65
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 59
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 54
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 49
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 44
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 40
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 36
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 33
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 30
# /data/jantina/Superpixels/Test/sparse_GT/train/KY-M1GOPR0778-Copy1.png
# (3000, 4000, 1)
# 500
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# 454
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# 412
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# 374
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# 339
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# 308
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# 279
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# 254
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# 230
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# 209
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# 190
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# 172
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# 156
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# 142
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# 129
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# 117
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# 106
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# 96
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# 87
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# 79
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# 72
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# 65
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# 59
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# 54
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# 49
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# 44
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# 40
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# 36
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# 33
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# 30
# /data/jantina/Superpixels/Test/sparse_GT/train/2020-08-10-AGAT-A-T5 6-Copy1.5-B (P8103499).png
# (3000, 4000, 1)
# [INFO] generation completed
