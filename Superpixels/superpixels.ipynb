# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

from PIL import Image
from skimage import io, transform

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")
# Out:
# /home/jantina/.local/lib/python3.8/site-packages/skimage/io/manage_plugins.py:23: UserWarning: Your installed pillow version is < 8.1.2. Several security issues (CVE-2021-27921, CVE-2021-25290, CVE-2021-25291, CVE-2021-25293, and more) have been fixed in pillow 8.1.2 or higher. We recommend to upgrade this library.
#   from .collection import imread_collection_wrapper

# %%
os.chdir("/home/jantina/CoralNet/ML-Superpixels/Datasets/Lizard_Heron_small/images")
img_name = "2020-06-23-ADELUP-A-T1 13.0-A (P6230525).JPG"
image = io.imread(os.path.join('train', img_name))
print(image.shape)
plt.imshow(image)
# Out:
# (3000, 4000, 3)

# %%
os.chdir("/home/jantina/CoralNet/ML-Superpixels/Datasets/Lizard_Heron_small/labels")
img_name = "2020-06-23-ADELUP-A-T1 13.0-A (P6230525).png"
image = io.imread(os.path.join('train', img_name))
print(image.shape)
print(np.unique(image))
plt.imshow(image, cmap = "tab20")
plt.colorbar()
# Out:
# (3000, 4000)
# [ 37  38  78  79  87 120 126 255]

# %%
os.chdir("/home/jantina/CoralNet/ML-Superpixels/Lizard_Heron_small/augmented_GT")
img_name = "2020-06-23-ADELUP-A-T1 13.0-A (P6230525).png"
image = io.imread(os.path.join('train', img_name))
print(image.shape)
print(np.unique(image))
plt.imshow(image, cmap = "tab20")
plt.colorbar()

print("number of levels = 20, 5000-30 superpixels")
# Out:
# (3000, 4000)
# [ 37  38  78  79  87 120 126 255]
# number of levels = 20, 5000-30 superpixels

# %%
os.chdir("/home/jantina/CoralNet/ML-Superpixels/Lizard_Heron_small/augmented_GT")
img_name = "2020-06-23-ADELUP-A-T1 13.0-A (P6230525).png"
image = io.imread(os.path.join('train', img_name))
print(image.shape)
print(np.unique(image))
plt.imshow(image, cmap = "tab20")
plt.colorbar()

print("number of levels = 20, 10000-30 superpixels")
# Out:
# (3000, 4000)
# [ 37  38  78  79  87 120 126 255]
# number of levels = 20, 10000-30 superpixels

# %%
os.chdir("/home/jantina/CoralNet/ML-Superpixels/Lizard_Heron_small/augmented_GT")
img_name = "2020-06-23-ADELUP-A-T1 13.0-A (P6230525).png"
image = io.imread(os.path.join('train', img_name))
print(image.shape)
print(np.unique(image))
plt.imshow(image, cmap = "tab20")
plt.colorbar()

print("number of levels = 50, 10000-30 superpixels")
# Out:
# (3000, 4000)
# [ 37  38  78  79  87 120 126 255]
# number of levels = 50, 10000-30 superpixels

# %%
os.chdir("/home/jantina/CoralNet/ML-Superpixels/Lizard_Heron_small/augmented_GT")
img_name = "2020-06-23-ADELUP-A-T1 13.0-A (P6230525).png"
image = io.imread(os.path.join('train', img_name))
print(image.shape)
print(np.unique(image))
plt.imshow(image, cmap = "tab20")
plt.colorbar()

print("number of levels = 100, 10000-30 superpixels")
# Out:
# (3000, 4000)
# [ 37  38  78  79  87 120 126 255]
# number of levels = 100, 10000-30 superpixels

# %%
cd CoralNet/ML-Superpixels
python3 generate_augmented_GT/generate_augmented_GT.py --dataset ./Datasets/Lizard_Heron_small --number_levels 500 --start_n_superpixels 10000 --last_n_superpixels 30
