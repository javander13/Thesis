# %%
# Import necessary libraries

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import glob
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

from sklearn.model_selection import train_test_split

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models

# %%
# labels for each class category of interest 

os.chdir("/data/jantina/CoralNet/WAPA_RFM")
labels = pd.read_csv('labelset.csv')["Short Code"]
labels.index = labels.index + 1
labels = labels.to_dict()

# %%
# Collect all of the patches for all of the classes created

data = glob.glob('/data/jantina/CoralNet/WAPA_RFM/patches/**/*.png', recursive = True)

# %%
data_dir = '/data/jantina/CoralNet/WAPA_RFM/patches/'

def load_split_train_test(datadir, valid_size = .2):
    
    train_transforms = transforms.Compose([transforms.Resize([224,224]),
                                           transforms.ToTensor()])
    
    test_transforms = transforms.Compose([transforms.Resize([224,224]),
                                          transforms.ToTensor()])
    
    train_data = datasets.ImageFolder(datadir,       
                    transform=train_transforms)
    
    test_data = datasets.ImageFolder(datadir,
                    transform=test_transforms)
    
    num_train = len(train_data)
    
    indices = list(range(num_train))
    
    split = int(np.floor(valid_size * num_train))
    
    np.random.shuffle(indices)
    
    from torch.utils.data.sampler import SubsetRandomSampler
    
    train_idx, test_idx = indices[split:], indices[:split]
    
    train_sampler = SubsetRandomSampler(train_idx)
    
    test_sampler = SubsetRandomSampler(test_idx)
    
    trainloader = torch.utils.data.DataLoader(train_data, sampler=train_sampler, batch_size=32)
    
    testloader = torch.utils.data.DataLoader(test_data, sampler=test_sampler, batch_size=32)
    
    return trainloader, testloader

trainloader, testloader = load_split_train_test(data_dir, .2)
print(trainloader.dataset.classes)
# Out:
# ['10', '101', '102', '103', '104', '106', '107', '108', '109', '110', '111', '112', '113', '114', '116', '117', '118', '119', '12', '120', '121', '122', '123', '125', '126', '127', '128', '13', '130', '131', '134', '14', '16', '20', '21', '22', '23', '26', '27', '29', '31', '35', '37', '38', '39', '44', '45', '48', '49', '57', '61', '62', '63', '68', '69', '70', '72', '74', '76', '78', '79', '8', '81', '82', '85', '86', '87', '9', '91', '92', '95', '96', '97', '99']

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = models.resnet50(pretrained=True)

# %%
for param in model.parameters():
    param.requires_grad = False
    
model.fc = nn.Sequential(nn.Linear(2048, 512),
                                 nn.ReLU(),
                                 nn.Dropout(0.2),
                                 nn.Linear(512, 74),
                                 nn.LogSoftmax(dim=1))
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.fc.parameters(), lr=0.003)
model.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=512, out_features=74, bias=True)
#     (4): LogSoftmax(dim=1)
#   )
# )

# %%
epochs = 1
steps = 0
running_loss = 0
print_every = 10
train_losses, test_losses = [], []

for epoch in range(epochs):
    for inputs, labels in trainloader:
        steps += 1
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        logps = model.forward(inputs)
        loss = criterion(logps, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        
        if steps % print_every == 0:
            test_loss = 0
            accuracy = 0
            model.eval()
            with torch.no_grad():
                for inputs, labels in testloader:
                    inputs, labels = inputs.to(device), labels.to(device)
                    logps = model.forward(inputs)
                    batch_loss = criterion(logps, labels)
                    test_loss += batch_loss.item()
                    
                    ps = torch.exp(logps)
                    top_p, top_class = ps.topk(1, dim=1)
                    equals = top_class == labels.view(*top_class.shape)
                    accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

            train_losses.append(running_loss/len(trainloader))
            test_losses.append(test_loss/len(testloader))                    
            print(f"Epoch {epoch+1}/{epochs}.. "
                  f"Train loss: {running_loss/print_every:.3f}.. "
                  f"Test loss: {test_loss/len(testloader):.3f}.. "
                  f"Test accuracy: {accuracy/len(testloader):.3f}")
            running_loss = 0
            model.train()
# Out:
# Epoch 1/1.. Train loss: 3.833.. Test loss: 2.719.. Test accuracy: 0.147
# Epoch 1/1.. Train loss: 2.320.. Test loss: 2.213.. Test accuracy: 0.312
# Epoch 1/1.. Train loss: 2.004.. Test loss: 1.940.. Test accuracy: 0.433
# Epoch 1/1.. Train loss: 2.044.. Test loss: 1.835.. Test accuracy: 0.457
# Epoch 1/1.. Train loss: 1.672.. Test loss: 1.794.. Test accuracy: 0.482
# Epoch 1/1.. Train loss: 1.736.. Test loss: 1.699.. Test accuracy: 0.478
# Epoch 1/1.. Train loss: 1.824.. Test loss: 1.678.. Test accuracy: 0.466
# Epoch 1/1.. Train loss: 1.725.. Test loss: 1.606.. Test accuracy: 0.522
# Epoch 1/1.. Train loss: 1.774.. Test loss: 1.598.. Test accuracy: 0.524
# Epoch 1/1.. Train loss: 1.715.. Test loss: 1.565.. Test accuracy: 0.528
# Epoch 1/1.. Train loss: 1.595.. Test loss: 1.520.. Test accuracy: 0.536
# Epoch 1/1.. Train loss: 1.604.. Test loss: 1.498.. Test accuracy: 0.560
# Epoch 1/1.. Train loss: 1.689.. Test loss: 1.490.. Test accuracy: 0.550
# Epoch 1/1.. Train loss: 1.662.. Test loss: 1.491.. Test accuracy: 0.546
# Epoch 1/1.. Train loss: 1.560.. Test loss: 1.485.. Test accuracy: 0.545
# Epoch 1/1.. Train loss: 1.592.. Test loss: 1.545.. Test accuracy: 0.507
# Epoch 1/1.. Train loss: 1.552.. Test loss: 1.527.. Test accuracy: 0.519
# Epoch 1/1.. Train loss: 1.628.. Test loss: 1.491.. Test accuracy: 0.542
# Epoch 1/1.. Train loss: 1.735.. Test loss: 1.552.. Test accuracy: 0.490
# Epoch 1/1.. Train loss: 1.501.. Test loss: 1.465.. Test accuracy: 0.547
# Epoch 1/1.. Train loss: 1.519.. Test loss: 1.431.. Test accuracy: 0.553
# Epoch 1/1.. Train loss: 1.551.. Test loss: 1.452.. Test accuracy: 0.551
# Epoch 1/1.. Train loss: 1.576.. Test loss: 1.455.. Test accuracy: 0.546
# Epoch 1/1.. Train loss: 1.536.. Test loss: 1.483.. Test accuracy: 0.532
# Epoch 1/1.. Train loss: 1.594.. Test loss: 1.447.. Test accuracy: 0.570
# Epoch 1/1.. Train loss: 1.565.. Test loss: 1.502.. Test accuracy: 0.538
# Epoch 1/1.. Train loss: 1.583.. Test loss: 1.377.. Test accuracy: 0.574
# Epoch 1/1.. Train loss: 1.585.. Test loss: 1.396.. Test accuracy: 0.576
# Epoch 1/1.. Train loss: 1.682.. Test loss: 1.401.. Test accuracy: 0.565
# Epoch 1/1.. Train loss: 1.398.. Test loss: 1.370.. Test accuracy: 0.574
# Epoch 1/1.. Train loss: 1.480.. Test loss: 1.474.. Test accuracy: 0.542
# Epoch 1/1.. Train loss: 1.502.. Test loss: 1.411.. Test accuracy: 0.575
# Epoch 1/1.. Train loss: 1.624.. Test loss: 1.429.. Test accuracy: 0.551
# Epoch 1/1.. Train loss: 1.491.. Test loss: 1.363.. Test accuracy: 0.593
# Epoch 1/1.. Train loss: 1.567.. Test loss: 1.414.. Test accuracy: 0.555
# Epoch 1/1.. Train loss: 1.530.. Test loss: 1.365.. Test accuracy: 0.576
# Epoch 1/1.. Train loss: 1.394.. Test loss: 1.460.. Test accuracy: 0.557
# Epoch 1/1.. Train loss: 1.572.. Test loss: 1.360.. Test accuracy: 0.580
# Epoch 1/1.. Train loss: 1.495.. Test loss: 1.353.. Test accuracy: 0.591
# Epoch 1/1.. Train loss: 1.396.. Test loss: 1.387.. Test accuracy: 0.566
# Epoch 1/1.. Train loss: 1.552.. Test loss: 1.400.. Test accuracy: 0.566
# Epoch 1/1.. Train loss: 1.542.. Test loss: 1.352.. Test accuracy: 0.579
# Epoch 1/1.. Train loss: 1.454.. Test loss: 1.333.. Test accuracy: 0.590
# Epoch 1/1.. Train loss: 1.471.. Test loss: 1.345.. Test accuracy: 0.577
# Epoch 1/1.. Train loss: 1.420.. Test loss: 1.392.. Test accuracy: 0.566
# Epoch 1/1.. Train loss: 1.519.. Test loss: 1.438.. Test accuracy: 0.543
# Epoch 1/1.. Train loss: 1.562.. Test loss: 1.362.. Test accuracy: 0.579
# Epoch 1/1.. Train loss: 1.705.. Test loss: 1.397.. Test accuracy: 0.578
# Epoch 1/1.. Train loss: 1.504.. Test loss: 1.357.. Test accuracy: 0.586
# Epoch 1/1.. Train loss: 1.652.. Test loss: 1.374.. Test accuracy: 0.586
# Epoch 1/1.. Train loss: 1.731.. Test loss: 1.340.. Test accuracy: 0.593
# Epoch 1/1.. Train loss: 1.514.. Test loss: 1.356.. Test accuracy: 0.574
# Epoch 1/1.. Train loss: 1.482.. Test loss: 1.398.. Test accuracy: 0.547
# Epoch 1/1.. Train loss: 1.613.. Test loss: 1.434.. Test accuracy: 0.554
# Epoch 1/1.. Train loss: 1.577.. Test loss: 1.364.. Test accuracy: 0.579
# Epoch 1/1.. Train loss: 1.611.. Test loss: 1.468.. Test accuracy: 0.546
# Epoch 1/1.. Train loss: 1.600.. Test loss: 1.369.. Test accuracy: 0.566
# Epoch 1/1.. Train loss: 1.490.. Test loss: 1.496.. Test accuracy: 0.549
# Epoch 1/1.. Train loss: 1.688.. Test loss: 1.355.. Test accuracy: 0.584
# Epoch 1/1.. Train loss: 1.371.. Test loss: 1.397.. Test accuracy: 0.573
# Epoch 1/1.. Train loss: 1.442.. Test loss: 1.368.. Test accuracy: 0.576
# Epoch 1/1.. Train loss: 1.616.. Test loss: 1.380.. Test accuracy: 0.579
# Epoch 1/1.. Train loss: 1.425.. Test loss: 1.445.. Test accuracy: 0.565
# Epoch 1/1.. Train loss: 1.561.. Test loss: 1.412.. Test accuracy: 0.557
# Epoch 1/1.. Train loss: 1.585.. Test loss: 1.373.. Test accuracy: 0.568
# Epoch 1/1.. Train loss: 1.460.. Test loss: 1.364.. Test accuracy: 0.571
# Epoch 1/1.. Train loss: 1.674.. Test loss: 1.392.. Test accuracy: 0.568
# Epoch 1/1.. Train loss: 1.568.. Test loss: 1.344.. Test accuracy: 0.584
# Epoch 1/1.. Train loss: 1.406.. Test loss: 1.364.. Test accuracy: 0.576
# Epoch 1/1.. Train loss: 1.532.. Test loss: 1.482.. Test accuracy: 0.555
# Epoch 1/1.. Train loss: 1.587.. Test loss: 1.435.. Test accuracy: 0.568
# Epoch 1/1.. Train loss: 1.705.. Test loss: 1.371.. Test accuracy: 0.563
# Epoch 1/1.. Train loss: 1.606.. Test loss: 1.378.. Test accuracy: 0.573
# Epoch 1/1.. Train loss: 1.438.. Test loss: 1.410.. Test accuracy: 0.568
# Epoch 1/1.. Train loss: 1.601.. Test loss: 1.391.. Test accuracy: 0.567
# Epoch 1/1.. Train loss: 1.526.. Test loss: 1.374.. Test accuracy: 0.582
# Epoch 1/1.. Train loss: 1.494.. Test loss: 1.357.. Test accuracy: 0.578
# Epoch 1/1.. Train loss: 1.436.. Test loss: 1.396.. Test accuracy: 0.578
# Epoch 1/1.. Train loss: 1.516.. Test loss: 1.403.. Test accuracy: 0.554
# Epoch 1/1.. Train loss: 1.525.. Test loss: 1.370.. Test accuracy: 0.579
# Epoch 1/1.. Train loss: 1.534.. Test loss: 1.361.. Test accuracy: 0.567
# Epoch 1/1.. Train loss: 1.451.. Test loss: 1.362.. Test accuracy: 0.589
# Epoch 1/1.. Train loss: 1.240.. Test loss: 1.384.. Test accuracy: 0.578
# Epoch 1/1.. Train loss: 1.512.. Test loss: 1.363.. Test accuracy: 0.579
# Epoch 1/1.. Train loss: 1.666.. Test loss: 1.391.. Test accuracy: 0.580
# Epoch 1/1.. Train loss: 1.428.. Test loss: 1.372.. Test accuracy: 0.590
# Epoch 1/1.. Train loss: 1.372.. Test loss: 1.355.. Test accuracy: 0.583
# Epoch 1/1.. Train loss: 1.505.. Test loss: 1.360.. Test accuracy: 0.590
# Epoch 1/1.. Train loss: 1.552.. Test loss: 1.359.. Test accuracy: 0.584
# Epoch 1/1.. Train loss: 1.555.. Test loss: 1.373.. Test accuracy: 0.567
# Epoch 1/1.. Train loss: 1.530.. Test loss: 1.320.. Test accuracy: 0.587
# Epoch 1/1.. Train loss: 1.467.. Test loss: 1.357.. Test accuracy: 0.577
# Epoch 1/1.. Train loss: 1.415.. Test loss: 1.338.. Test accuracy: 0.593
# Epoch 1/1.. Train loss: 1.461.. Test loss: 1.343.. Test accuracy: 0.590
# Epoch 1/1.. Train loss: 1.448.. Test loss: 1.366.. Test accuracy: 0.570
# Epoch 1/1.. Train loss: 1.647.. Test loss: 1.394.. Test accuracy: 0.567
# Epoch 1/1.. Train loss: 1.659.. Test loss: 1.330.. Test accuracy: 0.590
# Epoch 1/1.. Train loss: 1.523.. Test loss: 1.330.. Test accuracy: 0.594
# Epoch 1/1.. Train loss: 1.621.. Test loss: 1.327.. Test accuracy: 0.591
# Epoch 1/1.. Train loss: 1.408.. Test loss: 1.337.. Test accuracy: 0.585
# Epoch 1/1.. Train loss: 1.457.. Test loss: 1.416.. Test accuracy: 0.569
# Epoch 1/1.. Train loss: 1.539.. Test loss: 1.367.. Test accuracy: 0.579
# Epoch 1/1.. Train loss: 1.434.. Test loss: 1.338.. Test accuracy: 0.589
# Epoch 1/1.. Train loss: 1.441.. Test loss: 1.338.. Test accuracy: 0.591
# Epoch 1/1.. Train loss: 1.461.. Test loss: 1.356.. Test accuracy: 0.592
# Epoch 1/1.. Train loss: 1.398.. Test loss: 1.359.. Test accuracy: 0.584
# Epoch 1/1.. Train loss: 1.534.. Test loss: 1.316.. Test accuracy: 0.591
# Epoch 1/1.. Train loss: 1.494.. Test loss: 1.320.. Test accuracy: 0.589
# Epoch 1/1.. Train loss: 1.450.. Test loss: 1.328.. Test accuracy: 0.593
# Epoch 1/1.. Train loss: 1.490.. Test loss: 1.308.. Test accuracy: 0.597
# Epoch 1/1.. Train loss: 1.411.. Test loss: 1.293.. Test accuracy: 0.600
# Epoch 1/1.. Train loss: 1.519.. Test loss: 1.413.. Test accuracy: 0.569
# Epoch 1/1.. Train loss: 1.414.. Test loss: 1.291.. Test accuracy: 0.597
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [7], in <cell line: 7>()
#      21 model.eval()
#      22 with torch.no_grad():
# ---> 23     for inputs, labels in testloader:
#      24         inputs, labels = inputs.to(device), labels.to(device)
#      25         logps = model.forward(inputs)
#
# File ~/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py:521, in _BaseDataLoaderIter.__next__(self)
#     519 if self._sampler_iter is None:
#     520     self._reset()
# --> 521 data = self._next_data()
#     522 self._num_yielded += 1
#     523 if self._dataset_kind == _DatasetKind.Iterable and \
#     524         self._IterableDataset_len_called is not None and \
#     525         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py:561, in _SingleProcessDataLoaderIter._next_data(self)
#     559 def _next_data(self):
#     560     index = self._next_index()  # may raise StopIteration
# --> 561     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     562     if self._pin_memory:
#     563         data = _utils.pin_memory.pin_memory(data)
#
# File ~/.local/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:49, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      47 def fetch(self, possibly_batched_index):
#      48     if self.auto_collation:
# ---> 49         data = [self.dataset[idx] for idx in possibly_batched_index]
#      50     else:
#      51         data = self.dataset[possibly_batched_index]
#
# File ~/.local/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:49, in <listcomp>(.0)
#      47 def fetch(self, possibly_batched_index):
#      48     if self.auto_collation:
# ---> 49         data = [self.dataset[idx] for idx in possibly_batched_index]
#      50     else:
#      51         data = self.dataset[possibly_batched_index]
#
# File ~/.local/lib/python3.8/site-packages/torchvision/datasets/folder.py:234, in DatasetFolder.__getitem__(self, index)
#     232 sample = self.loader(path)
#     233 if self.transform is not None:
# --> 234     sample = self.transform(sample)
#     235 if self.target_transform is not None:
#     236     target = self.target_transform(target)
#
# File ~/.local/lib/python3.8/site-packages/torchvision/transforms/transforms.py:61, in Compose.__call__(self, img)
#      59 def __call__(self, img):
#      60     for t in self.transforms:
# ---> 61         img = t(img)
#      62     return img
#
# File ~/.local/lib/python3.8/site-packages/torchvision/transforms/transforms.py:98, in ToTensor.__call__(self, pic)
#      90 def __call__(self, pic):
#      91     """
#      92     Args:
#      93         pic (PIL Image or numpy.ndarray): Image to be converted to tensor.
#    (...)
#      96         Tensor: Converted image.
#      97     """
# ---> 98     return F.to_tensor(pic)
#
# File ~/.local/lib/python3.8/site-packages/torchvision/transforms/functional.py:148, in to_tensor(pic)
#     146 img = img.view(pic.size[1], pic.size[0], len(pic.getbands()))
#     147 # put it from HWC to CHW format
# --> 148 img = img.permute((2, 0, 1)).contiguous()
#     149 if isinstance(img, torch.ByteTensor):
#     150     return img.to(dtype=default_float_dtype).div(255)
#
# KeyboardInterrupt:

# %%
plt.plot(train_losses, label='Training loss')
plt.plot(test_losses, label='Validation loss')
plt.legend(frameon=False)
plt.show()

# %%
torch.save(model, 'model.pth')
